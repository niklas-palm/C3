# %%
import os
import json
import re
from __future__ import absolute_import, unicode_literals
#from .celery import app


#@app.task
def wordCount():

    wantedWords = ['han', 'hon', 'hen', 'den', 'denna', 'denne']
    #root = '/data/data/'
    root = '/home/ubuntu/test/data/'
    my_dict = {}
    print('hjhh')
    for file in getFiles(root):
        with open(root + file) as f:
            print(f)
            for line in f:
                if (len(line) > 0 and not line == '\n'):
                    line = line.strip() #Remove trailing and starting spaces
                    
                    parsedTweet = json.loads(line)


                    if not (parsedTweet["retweeted"]):


                        words = cleanTweet(parsedTweet)

                        for word in words:
                            if word in wantedWords: 
                                my_dict[word] = my_dict.get(word, 0) + 1
                                


    return(my_dict)

def cleanTweet(parsedString):
    words = parsedString["text"]
    words = re.sub('[^a-zA-Z\s]', '', words.lower()).split()
    return words

def getFiles(root):
    print('getfiles')
    for root, dirs, files in os.walk(root):
        for file in files:
            yield file

# %%
from __future__ import absolute_import, unicode_literals
from .celery import app

@app.task
def wordCount():
    return x + y

@app.task
def mul(x, y):
    return x * y

@app.task
def xsum(numbers):
    return sum(numbers)

# %%
def cleanTweet(parsedString):
    words = parsedString["text"]
    words = re.sub('[^a-zA-Z\s]', '', words.lower()).split()
    return words

def getFiles(root):
    print('getfiles')
    for root, dirs, files in os.walk(root):
        for file in files:
            yield file

# %%
res = wordCount()
print('hey')
print(res)
# Out:
# hjhh
# getfiles
# <open file u'/home/ubuntu/test/worker-2.log', mode 'r' at 0x7f6b28202c90>
# FAIL!
# [2018-10-10 14:44:26,723: WARNING/ForkPoolWorker-2] hjhh
# FAIL!
# [2018-10-10 14:44:26,724: WARNING/ForkPoolWorker-2] getfiles
# FAIL!
# [2018-10-10 14:44:26,724: WARNING/ForkPoolWorker-2] <open file u'/home/ubuntu/test/worker-2.log', mode 'r' at 0x7f268a02f6f0>
# FAIL!
# [2018-10-10 14:44:26,766: ERROR/ForkPoolWorker-2] Task code.tasks.wordCount[759295ee-0b7f-4801-aff3-2fe728e84de7] raised unexpected: ValueError('Expecting , delimiter: line 1 column 6 (char 5)',)
# FAIL!
# Traceback (most recent call last):
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/celery/app/trace.py", line 382, in trace_task
# FAIL!
# R = retval = fun(*args, **kwargs)
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/celery/app/trace.py", line 641, in __protected_call__
# FAIL!
# return self.run(*args, **kwargs)
# FAIL!
# File "/home/ubuntu/test/code/tasks.py", line 23, in wordCount
# FAIL!
# parsedTweet = json.loads(line)
# FAIL!
# File "/usr/lib/python2.7/json/__init__.py", line 339, in loads
# FAIL!
# return _default_decoder.decode(s)
# FAIL!
# File "/usr/lib/python2.7/json/decoder.py", line 364, in decode
# FAIL!
# obj, end = self.raw_decode(s, idx=_w(s, 0).end())
# FAIL!
# File "/usr/lib/python2.7/json/decoder.py", line 380, in raw_decode
# FAIL!
# obj, end = self.scan_once(s, idx)
# FAIL!
# ValueError: Expecting , delimiter: line 1 column 6 (char 5)
# FAIL!
# [2018-10-10 14:46:41,332: WARNING/ForkPoolWorker-2] hjhh
# FAIL!
# [2018-10-10 14:46:41,332: WARNING/ForkPoolWorker-2] getfiles
# FAIL!
# [2018-10-10 14:46:41,332: WARNING/ForkPoolWorker-2] <open file u'/home/ubuntu/test/worker-2.log', mode 'r' at 0x7f268a02f6f0>
# FAIL!
# [2018-10-10 14:46:41,334: ERROR/ForkPoolWorker-2] Task code.tasks.wordCount[07f6efdc-07e3-4f53-82fa-b0da9ee50059] raised unexpected: ValueError('Expecting , delimiter: line 1 column 6 (char 5)',)
# FAIL!
# Traceback (most recent call last):
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/celery/app/trace.py", line 382, in trace_task
# FAIL!
# R = retval = fun(*args, **kwargs)
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/celery/app/trace.py", line 641, in __protected_call__
# FAIL!
# return self.run(*args, **kwargs)
# FAIL!
# File "/home/ubuntu/test/code/tasks.py", line 23, in wordCount
# FAIL!
# parsedTweet = json.loads(line)
# FAIL!
# File "/usr/lib/python2.7/json/__init__.py", line 339, in loads
# FAIL!
# return _default_decoder.decode(s)
# FAIL!
# File "/usr/lib/python2.7/json/decoder.py", line 364, in decode
# FAIL!
# obj, end = self.raw_decode(s, idx=_w(s, 0).end())
# FAIL!
# File "/usr/lib/python2.7/json/decoder.py", line 380, in raw_decode
# FAIL!
# obj, end = self.scan_once(s, idx)
# FAIL!
# ValueError: Expecting , delimiter: line 1 column 6 (char 5)
# FAIL!
# [2018-10-10 14:53:27,071: WARNING/ForkPoolWorker-2] hjhh
# FAIL!
# [2018-10-10 14:53:27,071: WARNING/ForkPoolWorker-2] getfiles
# FAIL!
# [2018-10-10 14:53:27,072: WARNING/ForkPoolWorker-2] <open file u'/home/ubuntu/test/worker-2.log', mode 'r' at 0x7f268a02f6f0>
# FAIL!
# [2018-10-10 14:53:27,093: ERROR/ForkPoolWorker-2] Task code.tasks.wordCount[f9c6eb80-a652-4efb-ab2d-48c227265f40] raised unexpected: ValueError('Expecting , delimiter: line 1 column 6 (char 5)',)
# FAIL!
# Traceback (most recent call last):
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/celery/app/trace.py", line 382, in trace_task
# FAIL!
# R = retval = fun(*args, **kwargs)
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/celery/app/trace.py", line 641, in __protected_call__
# FAIL!
# return self.run(*args, **kwargs)
# FAIL!
# File "/home/ubuntu/test/code/tasks.py", line 23, in wordCount
# FAIL!
# parsedTweet = json.loads(line)
# FAIL!
# File "/usr/lib/python2.7/json/__init__.py", line 339, in loads
# FAIL!
# return _default_decoder.decode(s)
# FAIL!
# File "/usr/lib/python2.7/json/decoder.py", line 364, in decode
# FAIL!
# obj, end = self.raw_decode(s, idx=_w(s, 0).end())
# FAIL!
# File "/usr/lib/python2.7/json/decoder.py", line 380, in raw_decode
# FAIL!
# obj, end = self.scan_once(s, idx)
# FAIL!
# ValueError: Expecting , delimiter: line 1 column 6 (char 5)
# <open file u'/home/ubuntu/test/worker-1.log', mode 'r' at 0x7f6b28202c00>
# <open file u'/home/ubuntu/test/05cb5036-2170-401b-947d-68f9191b21c6', mode 'r' at 0x7f6b28202c90>
# <open file u'/home/ubuntu/test/worker.pid', mode 'r' at 0x7f6b28202db0>
# FAIL!
# 5343
# <open file u'/home/ubuntu/test/094b1612-1832-429e-98c1-ae06e56d88d6', mode 'r' at 0x7f6b28202ed0>
# <open file u'/home/ubuntu/test/worker.log', mode 'r' at 0x7f6b28202c90>
# FAIL!
# [2018-10-10 14:43:55,750: INFO/MainProcess] Connected to amqp://guest:**@127.0.0.1:5672//
# FAIL!
# [2018-10-10 14:43:55,776: INFO/MainProcess] mingle: searching for neighbors
# FAIL!
# [2018-10-10 14:43:56,814: INFO/MainProcess] mingle: all alone
# FAIL!
# [2018-10-10 14:43:56,836: INFO/MainProcess] worker@supersecretinstance ready.
# FAIL!
# [2018-10-10 14:44:26,722: INFO/MainProcess] Received task: code.tasks.wordCount[759295ee-0b7f-4801-aff3-2fe728e84de7]
# FAIL!
# [2018-10-10 14:46:41,331: INFO/MainProcess] Received task: code.tasks.wordCount[07f6efdc-07e3-4f53-82fa-b0da9ee50059]
# FAIL!
# [2018-10-10 14:52:53,716: INFO/MainProcess] sync with celery@supersecretinstance
# FAIL!
# [2018-10-10 14:52:53,717: ERROR/MainProcess] Control command error: error(104, 'Connection reset by peer')
# FAIL!
# Traceback (most recent call last):
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/celery/worker/pidbox.py", line 46, in on_message
# FAIL!
# self.node.handle_message(body, message)
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/kombu/pidbox.py", line 129, in handle_message
# FAIL!
# return self.dispatch(**body)
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/kombu/pidbox.py", line 112, in dispatch
# FAIL!
# ticket=ticket)
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/kombu/pidbox.py", line 135, in reply
# FAIL!
# serializer=self.mailbox.serializer)
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/kombu/pidbox.py", line 265, in _publish_reply
# FAIL!
# **opts
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/kombu/messaging.py", line 181, in publish
# FAIL!
# exchange_name, declare,
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/kombu/messaging.py", line 194, in _publish
# FAIL!
# [maybe_declare(entity) for entity in declare]
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/kombu/messaging.py", line 102, in maybe_declare
# FAIL!
# return maybe_declare(entity, self.channel, retry, **retry_policy)
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/kombu/common.py", line 129, in maybe_declare
# FAIL!
# return _maybe_declare(entity, declared, ident, channel, orig)
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/kombu/common.py", line 135, in _maybe_declare
# FAIL!
# entity.declare(channel=channel)
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/kombu/entity.py", line 185, in declare
# FAIL!
# nowait=nowait, passive=passive,
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/amqp/channel.py", line 614, in exchange_declare
# FAIL!
# wait=None if nowait else spec.Exchange.DeclareOk,
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/amqp/abstract_channel.py", line 50, in send_method
# FAIL!
# conn.frame_writer(1, self.channel_id, sig, args, content)
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/amqp/method_framing.py", line 166, in write_frame
# FAIL!
# write(view[:offset])
# FAIL!
# File "/home/ubuntu/.local/lib/python2.7/site-packages/amqp/transport.py", line 275, in write
# FAIL!
# self._write(s)
# FAIL!
# File "/usr/lib/python2.7/socket.py", line 228, in meth
# FAIL!
# return getattr(self._sock,name)(*args)
# FAIL!
# error: [Errno 104] Connection reset by peer
# FAIL!
# [2018-10-10 14:53:27,068: INFO/MainProcess] Received task: code.tasks.wordCount[f9c6eb80-a652-4efb-ab2d-48c227265f40]
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-6ca5a98f787a> in <module>()
# ----> 1 res = wordCount()
#       2 print('hey')
#       3 print(res)
#
# <ipython-input-5-0467ac04f72f> in wordCount()
#      15     print('hjhh')
#      16     for file in getFiles(root):
# ---> 17         with open(root + file) as f:
#      18             print(f)
#      19             for line in f:
#
# IOError: [Errno 2] No such file or directory: u'/home/ubuntu/test/__init__.py'
